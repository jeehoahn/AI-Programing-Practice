# %%
# !pip install pdfminer.six
# !pip install unstructured[pdf]
# !pip install sentence-transformers
# !pip install langchain unstructured openai chromadb Cython tiktoken pypdf

# %%
import os
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.document_loaders import PdfDocumentLoader  # 변경된 부분
from langchain.document_loaders import DirectoryLoader

from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.llms import OpenAI

from langchain.embeddings import LlamaCppEmbeddings, HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()

from google.colab import drive
drive.mount('/content/drive')

fn_dir = "/content/drive/My Drive/Colab Notebooks/pdf folder"
loader = DirectoryLoader(fn_dir)

# PDF 파일을 처리할 수 있는 로더로 변경
documents = PdfDocumentLoader(fn_dir).load()

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

db = Chroma.from_documents(docs, embedding=embeddings, persist_directory="school_index_hf")
db.persist()

query = "신입생 기숙사 신청 조건은?"
docs = db.similarity_search(query)

docs[4]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-554bd9485a18> in <cell line: 5>()
#       3 from langchain.vectorstores import Chroma
#       4 from langchain.embeddings import SentenceTransformerEmbeddings
# ----> 5 from langchain.document_loaders import PdfDocumentLoader  # 변경된 부분
#       6 from langchain.document_loaders import DirectoryLoader
#       7
#
# ImportError: cannot import name 'PdfDocumentLoader' from 'langchain.document_loaders' (/usr/local/lib/python3.10/dist-packages/langchain/document_loaders/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...
